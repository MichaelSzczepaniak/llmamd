# %%
import pandas as pd

pd.set_option('display.max_colwidth', None)

df_prompt_data = pd.read_csv("./data/prompt_log.csv")
df_prompt_data
# Out:
#           date prompt_component  version  class  \
# 0   2024-02-26          context        1      2
# 1   2024-02-26    prompt_prefix        1      0
# 2   2024-02-26    prompt_prefix        1      1
# 3   2024-02-27          context        2      2
# 4   2024-02-27    prompt_prefix        2      0
# 5   2024-02-27    prompt_prefix        2      1
# 6   2024-02-29          context        3      2
# 7   2024-02-29    prompt_prefix        3      0
# 8   2024-02-29    prompt_prefix        3      1
# 9   2024-03-23          context        4      0
# 10  2024-03-23          context        4      1
# 11  2024-03-23    prompt_prefix        4      0
# 12  2024-03-23    prompt_prefix        4      1
# 13  2024-03-28          context        5      0
# 14  2024-03-28          context        5      1
# 15  2024-03-28    prompt_prefix        5      0
# 16  2024-03-28    prompt_prefix        5      1
#
#                                                                                                                                                                         content  \
# 0                                                                                                      You are a fiction writer who has observed a disaster and likes to tweet.
# 1                                                                 Write me a tweet similar to this one, under 141 characters, but refers to a different activity and location:
# 2                                                                 Write me a tweet similar to this one, under 141 characters, but refers to a different disaster and location:
# 3                                                                                                      You are a fiction writer who has observed a disaster and likes to tweet.
# 4                                      Write me a tweet similar to this one, under 141 characters, does not use contractions, but refers to a different activity and location:
# 5                                      Write me a tweet similar to this one, under 141 characters, does not use contractions, but refers to a different disaster and location:
# 6                                                                                                      You are a fiction writer who has observed a disaster and likes to tweet.
# 7                 Write me a tweet similar to this one, under 141 characters, does not contain contractions or double quotes, but refers to a different activity and location:
# 8                 Write me a tweet similar to this one, under 141 characters, does not contain contractions or double quotes, but refers to a different disaster and location:
# 9                                                                                                    You are social commentator who enjoys diverse opinions and likes to tweet.
# 10                                                                                               You are a world class reporter who has observed a disaster and likes to tweet.
# 11                       Write me a tweet similar to this one, under 141 characters, does not contain double quotes, but refers to a different activity, feeling and location:
# 12                                Write me a tweet similar to this one, under 141 characters, does not contain double quotes, but refers to a different disaster and location:
# 13                                                                                                   You are social commentator who enjoys diverse opinions and likes to tweet.
# 14                                                                                               You are a world class reporter who has observed a disaster and likes to tweet.
# 15  Write me a tweet similar to this one in length and content, under 141 characters, does not contain double quotes but refers to a different activity, feeling and location:
# 16           Write me a tweet similar to this one in length and content, under 141 characters, does not contain double quotes but refers to a different disaster and location:
#
#                                                                                notes
# 0   initial context for both classes used for sending first API requests from Python
# 1                                       initial class 0 prompt used in web interface
# 2                                       initial class 1 prompt used in web interface
# 3                                                                  same as version 1
# 4                            avoid having to expand contractions on generated tweets
# 5                            avoid having to expand contractions on generated tweets
# 6                                                                  same as version 2
# 7                                             fix issue with generated tweet quoting
# 8                                             fix issue with generated tweet quoting
# 9                                           add context for class 0 generated tweets
# 10                                                 change fiction writer to reporter
# 11                                remove contraction constraint, add similar feeling
# 12                                                     remove contraction constraint
# 13                                                                 same as version 4
# 14                                                                 same as version 4
# 15                                                  add similar length specification
# 16                                                  add similar length specification

# %%
max_context_date = df_prompt_data.loc[df_prompt_data['prompt_component'] == 'context', 'date'].max()
max_prefix_c0_date = df_prompt_data.loc[(df_prompt_data['prompt_component'] == 'prompt_prefix') & \
                                        (df_prompt_data['class'] == 0), 'date'].max()
max_prefix_c1_date = df_prompt_data.loc[(df_prompt_data['prompt_component'] == 'prompt_prefix') & \
                                        (df_prompt_data['class'] == 1), 'date'].max()
print(max_context_date, max_prefix_c0_date, max_prefix_c1_date)

max_context_c0 = df_prompt_data.loc[(df_prompt_data['prompt_component'] == 'context') & \
                                 (df_prompt_data['date'] == max_context_date) & \
                                 (df_prompt_data['class'] == 0), 'content'].values[0]
max_context_c1 = df_prompt_data.loc[(df_prompt_data['prompt_component'] == 'context') & \
                                 (df_prompt_data['date'] == max_context_date) & \
                                 (df_prompt_data['class'] == 1), 'content'].values[0]

max_prompt_pre_c0 = df_prompt_data.loc[(df_prompt_data['prompt_component'] == 'prompt_prefix') & \
                                 (df_prompt_data['date'] == max_context_date) & \
                                 (df_prompt_data['class'] == 0), 'content'].values[0]
max_prompt_pre_c1 = df_prompt_data.loc[(df_prompt_data['prompt_component'] == 'prompt_prefix') & \
                                 (df_prompt_data['date'] == max_context_date) & \
                                 (df_prompt_data['class'] == 1), 'content'].values[0]

print(max_context_c0)
print(max_context_c1)
print(max_prompt_pre_c0)
print(max_prompt_pre_c1)
# Out:
# 2024-03-28 2024-03-28 2024-03-28
# You are social commentator who enjoys diverse opinions and likes to tweet.
# You are a world class reporter who has observed a disaster and likes to tweet.
# Write me a tweet similar to this one in length and content, under 141 characters, does not contain double quotes but refers to a different activity, feeling and location:
# Write me a tweet similar to this one in length and content, under 141 characters, does not contain double quotes but refers to a different disaster and location:

# %%
# test batch indices generation
import projtools as pt

indices_dict = pt.get_batch_indices()
print(indices_dict)
print()
# Out:
# {'tweet_batches_class0': [(0, 199), (200, 399), (400, 599), (600, 799), (800, 999), (1000, 1199), (1200, 1399), (1400, 1599), (1600, 1799), (1800, 1999), (2000, 2199), (2200, 2399), (2400, 2599), (2600, 2799), (2800, 2999), (3000, 3199), (3200, 3399), (3400, 3599), (3600, 3799), (3800, 3999), (4000, 4199), (4200, 4297)], 'tweet_batches_class1': [(0, 199), (200, 399), (400, 599), (600, 799), (800, 999), (1000, 1199), (1200, 1399), (1400, 1599), (1600, 1799), (1800, 1999), (2000, 2199), (2200, 2399), (2400, 2599), (2600, 2799), (2800, 2999), (3100, 3189)]}

# %%
# semi-manual augmented tweet generation - 4th batch, batch index = 3 as shown below
# class0_tweets_test = pt.generate_tweet_batch(class_label=0, context_by_class=max_context_c0, start_prompt_by_class=max_prompt_pre_c0,
#                                              batch_start=indices_dict['tweet_batches_class0'][3][0],
#                                              batch_end=indices_dict['tweet_batches_class0'][3][1])
# class1_tweets_test = pt.generate_tweet_batch(class_label=1, context_by_class=max_context_c1, start_prompt_by_class=max_prompt_pre_c1,
#                                              batch_start=indices_dict['tweet_batches_class1'][3][0],
#                                              batch_end=indices_dict['tweet_batches_class1'][3][1])
# Out:
# shape of tweet_csv_file: (7485, 4)
# generating augmented tweets for class: 0
# shape of df_by_class: (4297, 2)
# processing row 10 with id 21317
# processing row 20 with id 21334
# processing row 30 with id 21351
# processing row 40 with id 21369
# processing row 50 with id 21383
# processing row 60 with id 21396
# processing row 70 with id 21414
# processing row 80 with id 21432
# processing row 90 with id 21450
# processing row 100 with id 21466
# processing row 110 with id 21485
# processing row 120 with id 21499
# processing row 130 with id 21509
# processing row 140 with id 21522
# processing row 150 with id 21538
# processing row 160 with id 21568
# processing row 170 with id 21599
# processing row 180 with id 21619
# processing row 190 with id 21715
# processing row 200 with id 21766
# Augmented data file written successfully: True
# time to do 200 is 5.463240508238474 minutes
# shape of tweet_csv_file: (7485, 4)
# generating augmented tweets for class: 1
# shape of df_by_class: (3188, 2)
# processing row 10 with id 22388
# processing row 20 with id 22463
# processing row 30 with id 22483
# processing row 40 with id 22504
# processing row 50 with id 22519
# processing row 60 with id 22539
# processing row 70 with id 22564
# processing row 80 with id 22598
# processing row 90 with id 22625
# processing row 100 with id 22649
# processing row 110 with id 22755
# processing row 120 with id 22821
# processing row 130 with id 22841
# processing row 140 with id 22878
# processing row 150 with id 22895
# processing row 160 with id 22950
# processing row 170 with id 23012
# processing row 180 with id 23057
# processing row 190 with id 23077
# processing row 200 with id 23100
# Augmented data file written successfully: True
# time to do 200 is 5.651940635840098 minutes

# %%
# generate a couple of batches
for batch_index in [4, 5]:
    class0_tweets_test = pt.generate_tweet_batch(class_label=0, context_by_class=max_context_c0,
                                                 start_prompt_by_class=max_prompt_pre_c0,
                                                 batch_start=indices_dict['tweet_batches_class0'][batch_index][0],
                                                 batch_end=indices_dict['tweet_batches_class0'][batch_index][1])
    class1_tweets_test = pt.generate_tweet_batch(class_label=1, context_by_class=max_context_c1, start_prompt_by_class=max_prompt_pre_c1,
                                                 batch_start=indices_dict['tweet_batches_class1'][batch_index][0],
                                                 batch_end=indices_dict['tweet_batches_class1'][batch_index][1])
# Out:
# shape of tweet_csv_file: (7485, 4)
# generating augmented tweets for class: 0
# shape of df_by_class: (4297, 2)
# processing row 10 with id 21826
